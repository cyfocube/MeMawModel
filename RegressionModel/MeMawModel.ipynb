# %%
import scipy as sci
import joblib as job
import numpy as np
import pandas as pd
from sklearn import linear_model
from sklearn.linear_model import Ridge, Lasso, ElasticNet
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn import model_selection
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from sklearn.linear_model import RidgeCV, LassoCV,ElasticNetCV, MultiTaskLasso, MultiTaskElasticNetCV
from sklearn.linear_model import MultiTaskLassoCV
from sklearn.metrics import r2_score
from sklearn.datasets import make_regression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
#import statsmodels.api as sm
from sklearn.preprocessing import OneHotEncoder
import sklearn.metrics as sm

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#%matplotlib inline
from sklearn.linear_model import RidgeCV, LassoCV,ElasticNetCV
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

# %%
#Get Data
# %store -r y_inc_rent_score_train
# %store -r y_inc_rent_score_test
# %store -r x_inc_rent_score_train
# %store -r x_inc_rent_score_test
# %store -r y_inc_rent_data
# %store -r x_inc_rent_data
# %store -r int_rent_place

# %%
#Linear Regression
#from sklearn.linear_model import LinearRegression
#lin_inc_rent_model= LinearRegression(normalize=True)
#lin_inc_rent_model.fit(x_inc_rent_score_train, y_inc_rent_score_train)

lin_inc_rent_model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
lin_inc_rent_model.fit(x_inc_rent_data, y_inc_rent_data)
lin_pred = lin_inc_rent_model.predict(x_inc_rent_data)
lin_pred_df = pd.DataFrame(lin_pred, columns=['Predicted'])
int_rent_predicted = pd.DataFrame({'Place': int_rent_place['place'], 'State': int_rent_place['state'], 'Placeid': int_rent_place['Placeid'], 'Predicted': lin_pred_df['Predicted']})
int_rent_predicted.to_csv('int_rent_predicted.csv', index=False)

# %%
int_rent_predicted
# Out:
#           Place          State                       Placeid  Predicted
# 0          Olpe         Kansas             52800-Olpe-Kansas   0.641623
# 1        Oneida         Kansas           52900-Oneida-Kansas   0.631241
# 2         Osage         Kansas            53200-Osage-Kansas   0.639691
# 3          Otis         Kansas             53525-Otis-Kansas   0.649931
# 4         Palco         Kansas            54125-Palco-Kansas   0.611379
# ...         ...            ...                           ...        ...
# 22799  Piedmont  West Virginia  63604-Piedmont-West Virginia   0.595536
# 22800     Pinch  West Virginia     63772-Pinch-West Virginia   0.658508
# 22801  Quinwood  West Virginia  66412-Quinwood-West Virginia   0.604387
# 22802    Rupert  West Virginia    70828-Rupert-West Virginia   0.589242
# 22803   Spencer  West Virginia   75820-Spencer-West Virginia   0.594891
#
# [22804 rows x 4 columns]
